# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahabubjamil/ColabNotebook/blob/main/EDA_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Black Friday Datasets EDA and feature engineering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train = pd.read_csv('train.csv')
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17        10.0             A
# 1  1000001  P00248942      F  0-17        10.0             A
# 2  1000001  P00087842      F  0-17        10.0             A
# 3  1000001  P00085442      F  0-17        10.0             A
# 4  1000002  P00285442      M   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
df_train.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158106 entries, 0 to 158105
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     158106 non-null  int64
#  1   Product_ID                  158105 non-null  object
#  2   Gender                      158105 non-null  object
#  3   Age                         158105 non-null  object
#  4   Occupation                  158105 non-null  float64
#  5   City_Category               158105 non-null  object
#  6   Stay_In_Current_City_Years  158105 non-null  object
#  7   Marital_Status              158105 non-null  float64
#  8   Product_Category_1          158105 non-null  float64
#  9   Product_Category_2          109036 non-null  float64
#  10  Product_Category_3          48337 non-null   float64
#  11  Purchase                    158105 non-null  float64
# dtypes: float64(6), int64(1), object(5)
# ...

# %%
df_train.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  1.581060e+05  158105.000000   158105.000000       158105.000000
# mean   1.002978e+06       8.067297        0.410107            5.293685
# std    1.752236e+03       6.527835        0.491854            3.740971
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001447e+06       2.000000        0.000000            1.000000
# 50%    1.003026e+06       7.000000        0.000000            5.000000
# 75%    1.004449e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       109036.000000        48337.000000  158105.000000
# mean             9.856038           12.667418    9313.467689
# std              5.085280            4.119399    4981.745578
# min              2.000000            3.000000     185.000000
# ...

# %%
df_test = pd.read_csv("test.csv")
df_test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             1.0                 1.0
# 1                          0             0.0                 3.0
# 2                         4+             1.0                 5.0
# 3                         4+             1.0                 4.0
# 4                          1             0.0                 4.0
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
##df_final = pd.merge(df_train,df_test,how = "left")
##df_final.head()

# %%
##df_final.shape

# %%
df_train.shape
# Out:
# (158106, 12)

# %%
df_test.shape
# Out:
# (178630, 11)

# %%
df_final = df_train.append(df_test)
#df_final2 = pd.concat(df_train,df_test)
df_final.shape
# Out:
# <ipython-input-12-06a08569a68a>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_final = df_train.append(df_test)
# (336736, 12)

# %%
df_final.drop(['User_ID'], axis = 1,inplace = True)

# %%
df_final.head()
# Out:
#   Product_ID Gender   Age  Occupation City_Category  \
# 0  P00069042      F  0-17        10.0             A
# 1  P00248942      F  0-17        10.0             A
# 2  P00087842      F  0-17        10.0             A
# 3  P00085442      F  0-17        10.0             A
# 4  P00285442      M   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
#df_final= pd.get_dummies(df_final['Gender'],drop_first= 1)

# %%
df_final['Gender'] = df_final["Gender"].map({'F': 0, 'M': 1})
df_final.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042     0.0  0-17        10.0             A
# 1  P00248942     0.0  0-17        10.0             A
# 2  P00087842     0.0  0-17        10.0             A
# 3  P00085442     0.0  0-17        10.0             A
# 4  P00285442     1.0   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df_final['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25', nan],
#       dtype=object)

# %%
df_final['Age'] = df_final['Age'].map({'0-17':1, '55+': 7, '26-35': 3, '46-50' : 5, '51-55': 6, '36-45' : 4, '18-25': 2 })

# %%
df_final.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042     0.0  1.0        10.0             A
# 1  P00248942     0.0  1.0        10.0             A
# 2  P00087842     0.0  1.0        10.0             A
# 3  P00085442     0.0  1.0        10.0             A
# 4  P00285442     1.0  7.0        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
## second technique
#from sklearn import preprocessing
#le = preprocessing.LabelEncoder()
#df_final['Age'] = le.fit_transform(df_final['Age'])

# %%
df_city = pd.get_dummies(df_final['City_Category'],drop_first=1)

# %%
df_final = pd.concat([df_final,df_city],axis=1)
df_final.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042     0.0  1.0        10.0             A
# 1  P00248942     0.0  1.0        10.0             A
# 2  P00087842     0.0  1.0        10.0             A
# 3  P00085442     0.0  1.0        10.0             A
# 4  P00285442     1.0  7.0        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase  B  C
# 0                 NaN                 NaN    8370.0  0  0
# 1                 6.0                14.0   15200.0  0  0
# 2                 NaN                 NaN    1422.0  0  0
# ...

# %%
df_final = df_final.drop('City_Category',axis=1)

# %%
df_final.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042     0.0  1.0        10.0                          2
# 1  P00248942     0.0  1.0        10.0                          2
# 2  P00087842     0.0  1.0        10.0                          2
# 3  P00085442     0.0  1.0        10.0                          2
# 4  P00285442     1.0  7.0        16.0                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0             0.0                 3.0                 NaN                 NaN
# 1             0.0                 1.0                 6.0                14.0
# 2             0.0                12.0                 NaN                 NaN
# 3             0.0                12.0                14.0                 NaN
# 4             0.0                 8.0                 NaN                 NaN
#
#    Purchase  B  C
# 0    8370.0  0  0
# 1   15200.0  0  0
# 2    1422.0  0  0
# 3    1057.0  0  0
# ...

# %%
[features for features in df_final.columns if df_final[features].isnull().sum()>0 ]
# Out:
# ['Product_ID',
#  'Gender',
#  'Age',
#  'Occupation',
#  'Stay_In_Current_City_Years',
#  'Marital_Status',
#  'Product_Category_1',
#  'Product_Category_2',
#  'Product_Category_3',
#  'Purchase']

# %%
df_final.isnull().sum()
# Out:
# Product_ID                         1
# Gender                             1
# Age                                1
# Occupation                         1
# Stay_In_Current_City_Years         2
# Marital_Status                     2
# Product_Category_1                 2
# Product_Category_2            104332
# Product_Category_3            234035
# Purchase                      178631
# B                                  0
# C                                  0
# dtype: int64

# %%
sns.heatmap(df_final.isnull(),yticklabels= False,cmap='viridis')
# Out:
# <Axes: >

# %%
df_final['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
#its become discrete feature (replace nan value with Mode)

# %%
df_final['Product_Category_2'].value_counts()
# Out:
# 8.0     39266
# 14.0    34217
# 2.0     30473
# 16.0    26757
# 15.0    23269
# 5.0     15995
# 4.0     15916
# 6.0     10167
# 11.0     8748
# 17.0     8314
# 13.0     6517
# 9.0      3545
# 12.0     3410
# 10.0     1905
# 3.0      1786
# 18.0     1772
# 7.0       347
# Name: Product_Category_2, dtype: int64

# %%
df_final['Product_Category_2'].mode()[0]
# Out:
# 8.0

# %%
df_final['Product_Category_2'] = df_final['Product_Category_2'].fillna(df_final['Product_Category_2'].mode()[0])

# %%
df_final['Product_Category_2'].isnull().sum()
# Out:
# 0

# %%
df_final['Product_Category_3'].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df_final['Product_Category_3'].mode()[0]
df_final['Product_Category_3'] = df_final['Product_Category_3'].fillna(df_final['Product_Category_3'].mode()[0])
df_final['Product_Category_3'].isnull().sum()
# Out:
# 0

# %%
df_final.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042     0.0  1.0        10.0                          2
# 1  P00248942     0.0  1.0        10.0                          2
# 2  P00087842     0.0  1.0        10.0                          2
# 3  P00085442     0.0  1.0        10.0                          2
# 4  P00285442     1.0  7.0        16.0                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0             0.0                 3.0                 8.0                16.0
# 1             0.0                 1.0                 6.0                14.0
# 2             0.0                12.0                 8.0                16.0
# 3             0.0                12.0                14.0                16.0
# 4             0.0                 8.0                 8.0                16.0
#
#    Purchase  B  C
# 0    8370.0  0  0
# 1   15200.0  0  0
# 2    1422.0  0  0
# 3    1057.0  0  0
# ...

# %%
## extra work

# %%
df_final.columns
# Out:
# Index(['Product_ID', 'Gender', 'Age', 'Occupation',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase', 'B', 'C'],
#       dtype='object')

# %%
product_det = df_final.groupby(['Product_Category_1','Product_Category_2', 'Product_Category_3', 'Purchase']).size().reset_index().rename(columns={0:'result'})

# %%
product_det.head()
# Out:
#    Product_Category_1  Product_Category_2  Product_Category_3  Purchase  \
# 0                 1.0                 2.0                 3.0    3846.0
# 1                 1.0                 2.0                 3.0    3891.0
# 2                 1.0                 2.0                 3.0    3984.0
# 3                 1.0                 2.0                 3.0    4198.0
# 4                 1.0                 2.0                 3.0    4231.0
#
#    result
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)
sns.barplot(x='Product_Category_1',y='Purchase', data = product_det,palette=["blue","red"])
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='Purchase'>

# %%
df_final['Product_Category_1'].max()
# Out:
# 18.0

# %%
ocupatio_ped = df_final.Occupation.value_counts().index
Age_pred = df_final.Age.value_counts().values
plt.pie(Age_pred[0:5],labels=ocupatio_ped[0:5],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7bc3fb4ff9a0>,
# ...
#  [Text(0.24977573167550285, 1.0712665792723899, '4.0'),
#   Text(-1.0750156171698364, -0.23311246822286438, '0.0'),
#   Text(-0.07978499999179275, -1.0971027088546952, '7.0'),
#   Text(0.8043384097117997, -0.750359728838304, '1.0'),
#   Text(1.0696400616040802, -0.25665178474271283, '17.0')],
#  [Text(0.1362413081866379, 0.5843272250576671, '42.71%'),
#   Text(-0.5863721548199107, -0.12715225539428965, '21.38%'),
#   Text(-0.04351909090461422, -0.5984196593752882, '19.51%'),
#   Text(0.4387300416609816, -0.4092871248208931, '8.90%'),
#   Text(0.5834400336022255, -0.13999188258693426, '7.50%')])

# %%
df_final['Occupation'].max()
# Out:
# 20.0

# %%
df_final.groupby(['Stay_In_Current_City_Years','Purchase']).size().reset_index().rename(columns={0:'areaPurchase_list'})
# Out:
#       Stay_In_Current_City_Years  Purchase  areaPurchase_list
# 0                              0     185.0                  1
# 1                              0     197.0                  1
# 2                              0     210.0                  1
# 3                              0     215.0                  1
# 4                              0     216.0                  1
# ...                          ...       ...                ...
# 49327                         4+   23897.0                  1
# 49328                         4+   23904.0                  1
# 49329                         4+   23920.0                  1
# 49330                         4+   23932.0                  1
# 49331                         4+   23948.0                  1
#
# [49332 rows x 3 columns]

# %%
df_final[['Gender','Product_ID']].groupby([ 'Gender','Product_ID']).size().reset_index()
# Out:
#       Gender Product_ID    0
# 0        0.0  P00000142  197
# 1        0.0  P00000242   50
# 2        0.0  P00000342   47
# 3        0.0  P00000442   22
# 4        0.0  P00000542   35
# ...      ...        ...  ...
# 6728     1.0   P0099542    1
# 6729     1.0   P0099642    6
# 6730     1.0   P0099742   49
# 6731     1.0   P0099842   23
# 6732     1.0   P0099942    2
#
# [6733 rows x 3 columns]

# %%
#main work

# %%
df_final['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0', nan], dtype=object)

# %%
df_final['Stay_In_Current_City_Years'].value_counts()
# Out:
# 1     118749
# 2      62617
# 3      57947
# 4+     52064
# 0      45357
# Name: Stay_In_Current_City_Years, dtype: int64

# %%
df_final['Stay_In_Current_City_Years'] = df_final['Stay_In_Current_City_Years'].str.replace('+', '')
# Out:
# <ipython-input-50-13abe4d6a0be>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_final['Stay_In_Current_City_Years'] = df_final['Stay_In_Current_City_Years'].str.replace('+', '')

# %%
df_final['Stay_In_Current_City_Years'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    4
# Name: Stay_In_Current_City_Years, dtype: object

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 336736 entries, 0 to 178629
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  336735 non-null  object
#  1   Gender                      336735 non-null  float64
#  2   Age                         336735 non-null  float64
#  3   Occupation                  336735 non-null  float64
#  4   Stay_In_Current_City_Years  336734 non-null  object
#  5   Marital_Status              336734 non-null  float64
#  6   Product_Category_1          336734 non-null  float64
#  7   Product_Category_2          336736 non-null  float64
#  8   Product_Category_3          336736 non-null  float64
#  9   Purchase                    158105 non-null  float64
#  10  B                           336736 non-null  uint8
#  11  C                           336736 non-null  uint8
# dtypes: float64(8), object(2), uint8(2)
# ...

# %%
df = df_final

# %%
df['B'] = df['B'].astype(np.int64)

# %%
df['B'] = df['B'].astype(np.int64)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4', '3', '1', '0', nan], dtype=object)

# %%
df['Stay_In_Current_City_Years']= df['Stay_In_Current_City_Years'].fillna(df['Stay_In_Current_City_Years'].mode()[0])

# %%
df['Stay_In_Current_City_Years'].isnull().sum()
# Out:
# 0

# %%
##covert object into integers
df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].astype(np.int64)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 336736 entries, 0 to 178629
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  336735 non-null  object
#  1   Gender                      336735 non-null  float64
#  2   Age                         336735 non-null  float64
#  3   Occupation                  336735 non-null  float64
#  4   Stay_In_Current_City_Years  336736 non-null  int64
#  5   Marital_Status              336734 non-null  float64
#  6   Product_Category_1          336734 non-null  float64
#  7   Product_Category_2          336736 non-null  float64
#  8   Product_Category_3          336736 non-null  float64
#  9   Purchase                    158105 non-null  float64
#  10  B                           336736 non-null  int64
#  11  C                           336736 non-null  uint8
# dtypes: float64(8), int64(2), object(1), uint8(1)
# ...

# %%
#sns.barplot('Age','Purchase',hue='Gender', data= df)

# %%
df.drop(['Product_ID'],axis=1,inplace= True)

# %%
df.head(10)
# Out:
#    Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0     0.0  1.0        10.0                           2             0.0
# 1     0.0  1.0        10.0                           2             0.0
# 2     0.0  1.0        10.0                           2             0.0
# 3     0.0  1.0        10.0                           2             0.0
# 4     1.0  7.0        16.0                           4             0.0
# 5     1.0  3.0        15.0                           3             0.0
# 6     1.0  5.0         7.0                           2             1.0
# 7     1.0  5.0         7.0                           2             1.0
# 8     1.0  5.0         7.0                           2             1.0
# 9     1.0  3.0        20.0                           1             1.0
#
#    Product_Category_1  Product_Category_2  Product_Category_3  Purchase  B  C
# 0                 3.0                 8.0                16.0    8370.0  0  0
# ...

# %%
#feature scealing
df_test = df[df['Purchase'].isnull()]

# %%
df_train = df[~df['Purchase'].isnull()]

# %%
X=df_train.drop('Purchase',axis=1)

# %%
y = df_train['Purchase']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
